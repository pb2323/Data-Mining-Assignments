# %%
# !pip install pycaret[mlops] pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 1.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.8/165.8 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.3/105.3 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 1.6 MB/s eta 0:00:00
# ...
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 71.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 68.6 MB/s eta 0:00:00
# ...

# %%
from pycaret.datasets import get_data
from pycaret.regression import *
dataset = get_data('insurance')
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
test = setup(dataset, target='bmi', session_id=123)
# Out:
# <style type="text/css">
# #T_b48bd_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b48bd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b48bd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b48bd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b48bd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b48bd_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b48bd_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_b48bd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b48bd_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b48bd_row1_col1" class="data row1 col1" >bmi</td>
#     </tr>
#     <tr>
#       <th id="T_b48bd_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
dt = create_model('dt')
# Out:
# <style type="text/css">
# #T_a0487_row10_col0, #T_a0487_row10_col1, #T_a0487_row10_col2, #T_a0487_row10_col3, #T_a0487_row10_col4, #T_a0487_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_a0487" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0487_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_a0487_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_a0487_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_a0487_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_a0487_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_a0487_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
create_app(dt)
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://246af45e5a86cf2ee1.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://246af45e5a86cf2ee1.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
